# %%
import pandas as pd

# %%
polling_df = pd.read_csv('../election_resources/favorability_polls_rv_2019.csv')
polling_df.head()
# Out:
#    question_id start_date    end_date  pollster_id pollster   sponsors  \
# 0       114577  12/7/2019  12/10/2019          568   YouGov  Economist
# 1       114585  12/7/2019  12/10/2019          568   YouGov  Economist
# 2       114589  12/7/2019  12/10/2019          568   YouGov  Economist
# 3       114593  12/7/2019  12/10/2019          568   YouGov  Economist
# 4       114597  12/7/2019  12/10/2019          568   YouGov  Economist
#
#    sample_size population methodology  \
# 0         1195         rv      Online
# 1         1198         rv      Online
# 2         1198         rv      Online
# 3         1198         rv      Online
# 4         1202         rv      Online
#
#                                                  url         politician  \
# 0  https://d25d2506sfb94s.cloudfront.net/cumulus_...  Michael F. Bennet
# 1  https://d25d2506sfb94s.cloudfront.net/cumulus_...  Michael Bloomberg
# 2  https://d25d2506sfb94s.cloudfront.net/cumulus_...     Cory A. Booker
# ...

# %%
polling_df.tail()
# Out:
#       question_id start_date  end_date  pollster_id pollster  \
# 1626        95062   1/3/2019  1/4/2019         1416  HarrisX
# 1627        95064   1/3/2019  1/4/2019         1416  HarrisX
# 1628        95071   1/3/2019  1/4/2019         1416  HarrisX
# 1629        95084   1/3/2019  1/4/2019         1416  HarrisX
# 1630        95088   1/3/2019  1/4/2019         1416  HarrisX
#
#                 sponsors  sample_size population methodology  \
# 1626  ScottRasmussen.com         1003         rv      Online
# 1627  ScottRasmussen.com         1003         rv      Online
# 1628  ScottRasmussen.com         1003         rv      Online
# 1629  ScottRasmussen.com         1003         rv      Online
# 1630  ScottRasmussen.com         1003         rv      Online
#
#                                                     url        politician  \
# 1626      https://scottrasmussen.com/crosstabs-jan-3-4/        Tom Steyer
# 1627      https://scottrasmussen.com/crosstabs-jan-3-4/     Julián Castro
# ...

# %%
polling_df.describe()
# Out:
#          question_id  pollster_id  sample_size    favorable  unfavorable  \
# count    1631.000000  1631.000000  1631.000000  1631.000000  1631.000000
# mean   101904.902514   836.244635  1263.738197    27.369651    32.833476
# std      6561.371161   390.365914   347.533032    12.322381    12.386363
# min     94880.000000    11.000000   442.000000     2.000000     6.000000
# 25%     96842.500000   568.000000  1072.500000    17.000000    22.000000
# 50%     99386.000000   568.000000  1181.000000    27.000000    33.000000
# 75%    104004.000000  1189.000000  1268.000000    38.000000    42.000000
# max    114836.000000  1508.000000  2531.000000    56.000000    58.000000
#
#        very_favorable  somewhat_favorable  somewhat_unfavorable  \
# count     1390.000000         1390.000000           1390.000000
# mean        10.675396           16.431007             10.995036
# std          7.821444            5.910113              3.502219
# ...

# %%
polling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   question_id           1631 non-null   int64
#  1   start_date            1631 non-null   object
#  2   end_date              1631 non-null   object
#  3   pollster_id           1631 non-null   int64
#  4   pollster              1631 non-null   object
#  5   sponsors              1536 non-null   object
#  6   sample_size           1631 non-null   int64
#  7   population            1631 non-null   object
#  8   methodology           1631 non-null   object
#  9   url                   1631 non-null   object
#  10  politician            1631 non-null   object
#  11  favorable             1631 non-null   float64
#  12  unfavorable           1631 non-null   float64
#  13  very_favorable        1390 non-null   float64
#  14  somewhat_favorable    1390 non-null   float64
# ...

# %%
polling_df.drop(columns=['start_date', 'pollster_id', 'sponsors', 'methodology', 'url'], inplace=True)
polling_df.head()
# Out:
#    question_id    end_date pollster  sample_size population  \
# 0       114577  12/10/2019   YouGov         1195         rv
# 1       114585  12/10/2019   YouGov         1198         rv
# 2       114589  12/10/2019   YouGov         1198         rv
# 3       114593  12/10/2019   YouGov         1198         rv
# 4       114597  12/10/2019   YouGov         1202         rv
#
#           politician  favorable  unfavorable  very_favorable  \
# 0  Michael F. Bennet       14.0         29.0             4.0
# 1  Michael Bloomberg       24.0         58.0             7.0
# 2     Cory A. Booker       35.0         45.0            11.0
# 3      Steve Bullock       14.0         27.0             3.0
# 4     Pete Buttigieg       35.0         44.0            14.0
#
#    somewhat_favorable  somewhat_unfavorable  very_unfavorable
# 0                10.0                  12.0              17.0
# 1                17.0                  20.0              38.0
# ...

# %%
end_date = pd.to_datetime(polling_df['end_date'], format='%m/%d/%Y')

# %%
polling_df['end_date'] = end_date

# %%
polling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   question_id           1631 non-null   int64
#  1   end_date              1631 non-null   datetime64[ns]
#  2   pollster              1631 non-null   object
#  3   sample_size           1631 non-null   int64
#  4   population            1631 non-null   object
#  5   politician            1631 non-null   object
#  6   favorable             1631 non-null   float64
#  7   unfavorable           1631 non-null   float64
#  8   very_favorable        1390 non-null   float64
#  9   somewhat_favorable    1390 non-null   float64
#  10  somewhat_unfavorable  1390 non-null   float64
#  11  very_unfavorable      1389 non-null   float64
#  12  start_date            1631 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(2), object(3)
# memory usage: 165.8+ KB

# %%
polling_df.drop(columns=['start_date'], inplace=True)
polling_df.head()
# Out:
#    question_id   end_date pollster  sample_size population         politician  \
# 0       114577 2019-12-10   YouGov         1195         rv  Michael F. Bennet
# 1       114585 2019-12-10   YouGov         1198         rv  Michael Bloomberg
# 2       114589 2019-12-10   YouGov         1198         rv     Cory A. Booker
# 3       114593 2019-12-10   YouGov         1198         rv      Steve Bullock
# 4       114597 2019-12-10   YouGov         1202         rv     Pete Buttigieg
#
#    favorable  unfavorable  very_favorable  somewhat_favorable  \
# 0       14.0         29.0             4.0                10.0
# 1       24.0         58.0             7.0                17.0
# 2       35.0         45.0            11.0                24.0
# 3       14.0         27.0             3.0                11.0
# 4       35.0         44.0            14.0                21.0
#
#    somewhat_unfavorable  very_unfavorable
# 0                  12.0              17.0
# ...

# %%
polling_df['politician'].unique()
# Out:
# array(['Michael F. Bennet', 'Michael Bloomberg', 'Cory A. Booker',
#        'Steve Bullock', 'Pete Buttigieg', 'Julián Castro',
#        'John K. Delaney', 'Tulsi Gabbard', 'Amy Klobuchar',
#        'Deval Patrick', 'Tom Steyer', 'Marianne Williamson',
#        'Andrew Yang', 'Bernard Sanders', 'Elizabeth Warren',
#        'Joseph R. Biden Jr.', 'Donald Trump', 'Kamala D. Harris',
#        'Joe Sestak', 'Wayne Messam', "Beto O'Rourke", 'Tim Ryan',
#        'Bill de Blasio', 'Kirsten E. Gillibrand', 'Jay Robert Inslee',
#        'Seth Moulton', 'John Hickenlooper', 'Mike Gravel',
#        'Eric Swalwell', 'Stacey Yvonne Abrams', 'Sherrod Brown',
#        'Eric H. Holder', 'Terry R. McAuliffe', 'Eric Garcetti'],
#       dtype=object)

# %%
results = {'Michael F. Bennet': 'out', 'Michael Bloomberg': 'out', 'Cory A. Booker': 'out',
       'Steve Bullock': 'out', 'Pete Buttigieg': 'out', 'Julián Castro': 'out',
       'John K. Delaney': 'out', 'Tulsi Gabbard': 'out', 'Amy Klobuchar': 'out',
       'Deval Patrick': 'out', 'Tom Steyer': 'out', 'Marianne Williamson': 'out',
       'Andrew Yang': 'out', 'Bernard Sanders': 'out', 'Elizabeth Warren': 'out',
       'Joseph R. Biden Jr.': 'in', 'Donald Trump': 'in', 'Kamala D. Harris': 'out',
       'Joe Sestak': 'out', 'Wayne Messam': 'out', "Beto O'Rourke": 'out', 'Tim Ryan': 'out',
       'Bill de Blasio': 'out', 'Kirsten E. Gillibrand': 'out', 'Jay Robert Inslee': 'out',
       'Seth Moulton': 'out', 'John Hickenlooper': 'out', 'Mike Gravel': 'out',
       'Eric Swalwell': 'out', 'Stacey Yvonne Abrams': 'out', 'Sherrod Brown': 'out',
       'Eric H. Holder': 'out', 'Terry R. McAuliffe': 'out', 'Eric Garcetti': 'out'}

# %%
polling_df['results'] = polling_df['politician'].apply(lambda x: results.get(x))
polling_df.head()
# Out:
#    question_id   end_date pollster  sample_size population         politician  \
# 0       114577 2019-12-10   YouGov         1195         rv  Michael F. Bennet
# 1       114585 2019-12-10   YouGov         1198         rv  Michael Bloomberg
# 2       114589 2019-12-10   YouGov         1198         rv     Cory A. Booker
# 3       114593 2019-12-10   YouGov         1198         rv      Steve Bullock
# 4       114597 2019-12-10   YouGov         1202         rv     Pete Buttigieg
#
#    favorable  unfavorable  very_favorable  somewhat_favorable  \
# 0       14.0         29.0             4.0                10.0
# 1       24.0         58.0             7.0                17.0
# 2       35.0         45.0            11.0                24.0
# 3       14.0         27.0             3.0                11.0
# 4       35.0         44.0            14.0                21.0
#
#    somewhat_unfavorable  very_unfavorable results
# 0                  12.0              17.0     out
# ...

# %%
polling_df.to_csv('../election_resources/cleaned_2019_data.csv', index=False)
polling_df.to_json('../election_resources/cleaned_2019_data.json', orient='records')
