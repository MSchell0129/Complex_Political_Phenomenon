# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
polling_df = pd.read_csv('../election_resources/presidential_polls.csv')
polling_df.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
#
#       state   startdate     enddate                  pollster grade  ...  \
# 0      U.S.  10/25/2016  10/31/2016   Google Consumer Surveys     B  ...
# 1      U.S.  10/27/2016  10/30/2016  ABC News/Washington Post    A+  ...
# 2  Virginia  10/27/2016  10/30/2016  ABC News/Washington Post    A+  ...
# 3   Florida  10/20/2016  10/24/2016                 SurveyUSA     A  ...
# 4      U.S.  10/20/2016  10/25/2016       Pew Research Center    B+  ...
#
# ...

# %%
polling_df.tail()
# Out:
#        cycle     branch        type                        matchup  \
# 10231   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 10232   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 10233   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 10234   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 10235   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate           state  startdate     enddate  \
# 10231      11/1/16         Alabama  9/30/2016  10/13/2016
# 10232      11/1/16        Virginia  9/30/2016   10/6/2016
# 10233      11/1/16        Virginia  9/16/2016   9/22/2016
# 10234      11/1/16  North Carolina  6/20/2016   6/21/2016
# 10235      11/1/16            Utah  7/29/2016   8/18/2016
#
#                     pollster grade  ...  adjpoll_clinton adjpoll_trump  \
# 10231                  Ipsos    A-  ...         37.30964      54.76821
# ...

# %%
polling_df.describe()
# Out:
#          cycle    samplesize       poll_wt  rawpoll_clinton  rawpoll_trump  \
# count  10236.0  10233.000000  10236.000000     10236.000000   10236.000000
# mean    2016.0   1115.791557      0.221769        41.717579      39.227002
# std        0.0   2159.610968      0.535846         7.482747       7.648679
# min     2016.0     35.000000      0.000000        11.040000       4.000000
# 25%     2016.0    440.000000      0.000444        38.000000      34.877500
# 50%     2016.0    772.000000      0.008206        43.000000      39.000000
# 75%     2016.0   1225.000000      0.101939        46.000000      44.000000
# max     2016.0  40816.000000      7.591351        88.000000      68.000000
#
#        rawpoll_johnson  rawpoll_mcmullin  adjpoll_clinton  adjpoll_trump  \
# count      6480.000000         51.000000     10236.000000   10236.000000
# mean          7.713394         23.235294        43.024900      42.048617
# ...

# %%
polling_df.columns
# Out:
# Index(['cycle', 'branch', 'type', 'matchup', 'forecastdate', 'state',
#        'startdate', 'enddate', 'pollster', 'grade', 'samplesize', 'population',
#        'poll_wt', 'rawpoll_clinton', 'rawpoll_trump', 'rawpoll_johnson',
#        'rawpoll_mcmullin', 'adjpoll_clinton', 'adjpoll_trump',
#        'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions', 'url',
#        'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')

# %%
polling_df.drop(columns=['pollster', 'grade', 'rawpoll_clinton', 'rawpoll_trump', 'rawpoll_johnson',
       'rawpoll_mcmullin', 'url', 'question_id', 'createddate', 'timestamp'], inplace=True)

# %% [markdown]
# lv = likely voter
# rv = registered voters
# a = adult
# v = voters

# %%
polling_df['population'].unique()
# Out:
# array(['lv', 'rv', 'a', 'v'], dtype=object)

# %%
polling_df = polling_df.fillna(0)

# %%
polling_df.dtypes
# Out:
# cycle                 int64
# branch               object
# type                 object
# matchup              object
# forecastdate         object
# state                object
# startdate            object
# enddate              object
# samplesize          float64
# population           object
# poll_wt             float64
# adjpoll_clinton     float64
# adjpoll_trump       float64
# adjpoll_johnson     float64
# adjpoll_mcmullin    float64
# multiversions        object
# poll_id               int64
# dtype: object

# %%
polling_df.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
#
#       state   startdate     enddate  samplesize population   poll_wt  \
# 0      U.S.  10/25/2016  10/31/2016     24316.0         lv  6.139129
# 1      U.S.  10/27/2016  10/30/2016      1128.0         lv  4.197292
# 2  Virginia  10/27/2016  10/30/2016      1024.0         lv  3.876856
# 3   Florida  10/20/2016  10/24/2016      1251.0         lv  3.403096
# 4      U.S.  10/20/2016  10/25/2016      2120.0         rv  3.394646
#
#    adjpoll_clinton  adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
abb = {'lv': 'likely voters', 'rv': 'registered voters', 'a': 'adults', 'v': 'voters'}

# %%
polling_df['population']= polling_df['population'].replace(abb)
polling_df.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/1/16
#
#       state   startdate     enddate  samplesize         population   poll_wt  \
# 0      U.S.  10/25/2016  10/31/2016     24316.0      likely voters  6.139129
# 1      U.S.  10/27/2016  10/30/2016      1128.0      likely voters  4.197292
# 2  Virginia  10/27/2016  10/30/2016      1024.0      likely voters  3.876856
# 3   Florida  10/20/2016  10/24/2016      1251.0      likely voters  3.403096
# 4      U.S.  10/20/2016  10/25/2016      2120.0  registered voters  3.394646
#
# ...

# %%
polling_df['multiversions'] = pd.to_numeric(polling_df['multiversions'], errors='coerce')
polling_df['multiversions'] = polling_df['multiversions'].astype(float)

# %%
polling_df.dtypes
# Out:
# cycle                 int64
# branch               object
# type                 object
# matchup              object
# forecastdate         object
# state                object
# startdate            object
# enddate              object
# samplesize          float64
# population           object
# poll_wt             float64
# adjpoll_clinton     float64
# adjpoll_trump       float64
# adjpoll_johnson     float64
# adjpoll_mcmullin    float64
# multiversions       float64
# poll_id               int64
# dtype: object

# %%
polling_df.to_csv('../election_resources/cleaned_2016_polls.csv')

# %%
polling_df.to_json('../election_resources/cleaned_2016_polling.json')
