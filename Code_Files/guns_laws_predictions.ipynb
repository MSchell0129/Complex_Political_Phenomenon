# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import tensorflow as tf
import keras_tuner as kt
import keras as kr

# %%
guns_and_deaths = pd.read_csv('../Resources/Crime_Data/state_gun_and_deathrate.csv')
guns_and_deaths.head(20)
# Out:
#    state  year  felony  invcommitment  invoutpatient  danger  drugmisdemeanor  \
# 0     AL  2005       0              0              0       0                0
# 1     AL  2014       0              0              0       0                0
# 2     AL  2015       0              1              0       1                0
# 3     AL  2016       0              1              0       1                0
# 4     AL  2017       0              1              0       1                0
# 5     AL  2018       0              1              0       1                0
# 6     AL  2019       0              1              0       1                0
# 7     AL  2020       0              1              0       1                0
# 8     AK  2005       1              0              0       0                0
# 9     AK  2014       1              0              0       0                0
# 10    AK  2015       1              0              0       0                0
# ...

# %%
print(guns_and_deaths[guns_and_deaths['state'] == ''])
# Out:
#   state  year  felony  invcommitment  invoutpatient  danger  drugmisdemeanor  \
# 0    AL  2005       0              0              0       0                0
# 1    AL  2014       0              0              0       0                0
# 2    AL  2015       0              1              0       1                0
# 3    AL  2016       0              1              0       1                0
# 4    AL  2017       0              1              0       1                0
# 5    AL  2018       0              1              0       1                0
# 6    AL  2019       0              1              0       1                0
# 7    AL  2020       0              1              0       1                0
#
#    alctreatment  alcoholism  relinquishment  ...  dvrosurrendernoconditions  \
# 0             0           1               0  ...                          0
# 1             0           1               0  ...                          0
# ...

# %%
guns_and_deaths.describe()
# Out:
#               year     felony  invcommitment  invoutpatient      danger  \
# count   400.000000  400.00000     400.000000     400.000000  400.000000
# mean   2015.500000    0.73250       0.560000       0.305000    0.517500
# std       4.392977    0.44321       0.497009       0.460984    0.500319
# min    2005.000000    0.00000       0.000000       0.000000    0.000000
# 25%    2014.750000    0.00000       0.000000       0.000000    0.000000
# 50%    2016.500000    1.00000       1.000000       0.000000    1.000000
# 75%    2018.250000    1.00000       1.000000       1.000000    1.000000
# max    2020.000000    1.00000       1.000000       1.000000    1.000000
#
#        drugmisdemeanor  alctreatment  alcoholism  relinquishment     violent  \
# count       400.000000    400.000000  400.000000      400.000000  400.000000
# mean          0.197500      0.115000    0.122500        0.122500    0.075000
# std           0.398611      0.319421    0.328273        0.328273    0.263721
# ...

# %%
guns_and_deaths['plus5'] = guns_and_deaths['year'] + 5

# %%
guns_and_deaths['Delta'] = guns_and_deaths.apply(lambda row: row['Year'] - row['Total Guns'], axis=1)
