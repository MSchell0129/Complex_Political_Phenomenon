# %%
import pandas as pd

# %%
df = pd.read_csv('Resources/Crime_Data/national_crime.csv')
df = df.drop('id', axis=1)

# %%
grouped_df = df.groupby(['data_year', 'State']).sum().reset_index()
grouped_df.head(20)
# Out:
#     data_year State  Firearm (Automatic)  Handgun (Automatic)  \
# 0        1991    AL                    0                    0
# 1        1991    IL                    0                    2
# 2        1991    ND                    0                    1
# 3        1991    SC                    1                  219
# 4        1992    AL                    0                    0
# 5        1992    CO                    1                    0
# 6        1992    IA                   12                   79
# 7        1992    ID                   11                   62
# 8        1992    IL                    1                    0
# 9        1992    ND                    0                    0
# 10       1992    SC                    2                  294
# 11       1993    CO                    0                    0
# 12       1993    IA                   10                  136
# 13       1993    ID                   11                  183
# 14       1993    IL                   38                  234
# 15       1993    ND                    1                    3
# 16       1993    SC                    1                  208
# 17       1993    UT                    2                   23
# 18       1993    VT                    0                    0
# 19       1994    CO                    0                    1
#
#     Rifle (Automatic)  Rifle  Shotgun (Automatic)  Other Firearm (Automatic)  \
# 0                   0    239                    0                          0
# 1                   0      0                    0                          0
# 2                   0      3                    0                          0
# 3                   7    585                    2                          0
# 4                   0    238                    0                          0
# 5                   0      2                    0                          0
# 6                   8     82                    4                          2
# 7                   8     72                    0                          3
# 8                   0      0                    0                          0
# 9                   0      1                    0                          0
# 10                  8    600                    4                          3
# 11                  0      3                    0                          0
# 12                 13    115                    3                          4
# 13                 13    119                    6                          4
# 14                  3    241                    2                          2
# 15                  0      5                    0                          0
# 16                  3    570                    0                          4
# 17                  0     24                    0                          0
# 18                  0      0                    0                          0
# 19                  0      2                    0                          0
#
#     Firearm  Handgun  Shotgun  Other Firearm
# 0      1385     7359      705              0
# 1         3        1        0              0
# 2         4       10        1              3
# 3       909     8199     1321            191
# 4      1442     6310      563              0
# 5        13       56        4              7
# 6       178      424      151             43
# 7        69      253       73             39
# 8         0        2        0              0
# 9         3       14        3              0
# 10      617     9553     1412             94
# 11        3       71        8              7
# 12      264      729      225             90
# 13      119      484       84            110
# 14      707     5049      435            267
# 15        3       10        8              4
# 16      530     8363      976            129
# 17       42       61       15             26
# 18        0        0        0              0
# 19        1       30        1              2

# %%
grouped_df.to_csv('Resources/Crime_Data/national_crime_by_year.csv', index=False)
